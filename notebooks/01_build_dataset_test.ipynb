# %%
import sys
sys.path.append('..')
from src.data.preprocessing import build_main_dataset
import pandas as pd
import os

# %%
# TESTE RÁPIDO: só PETR4 + IBOV
print("Iniciando teste...")

df = build_main_dataset(
    target_ticker="PETR4.SA",
    target_name="petr4",
    aux_tickers={"^BVSP": "ibov"},  # só um ativo pra testar rápido
    start="2023-01-01",  # dados recentes = mais rápido
    end="2023-12-31"
)

print("SUCESSO!")
print(df.head())
print(f"\nTotal de linhas: {len(df)}")
print(f"Colunas: {list(df.columns)}")
# Out:
# Iniciando teste...
# Carregando PETR4.SA de data/raw\PETR4.SA_2023-01-01_2023-12-31.csv
# Carregando ^BVSP de data/raw\BVSP_2023-01-01_2023-12-31.csv
# Dataset final salvo em data/processed/petr4_completo.csv
# SUCESSO!
#                 petr4     Volume      ibov
# Date
# 2023-01-02  13.380751   78424700  106376.0
# 2023-01-03  13.042144   96750300  104166.0
# 2023-01-04  13.456644  129504000  105334.0
# 2023-01-05  13.941200   73886000  107518.0
# 2023-01-06  13.859466   51851500  108836.0
#
# Total de linhas: 248
# Colunas: ['petr4', 'Volume', 'ibov']
